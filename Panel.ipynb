# %%
import pandas as pd

# %%
from pandas_datareader import data

# %%
co=["MSFT","AAPL","AMZN","YHOO","GOOG"]
p=data.DataReader(name=co,data_source="yahoo",start="2010-01-01",end="2019-01-01")
type(p)
# Out:
# D:\study\anaconda\lib\site-packages\pandas_datareader\base.py:230: SymbolWarning: Failed to read symbol: 'YHOO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# pandas.core.frame.DataFrame

# %%
p.items
# Out:
# <bound method DataFrame.iteritems of Attributes        High                                                    Low  \
# Symbols           AAPL         AMZN         GOOG        MSFT YHOO        AAPL
# Date
# 2009-12-31   30.478571   137.279999   310.679321   30.990000  NaN   30.080000
# 2010-01-04   30.642857   136.610001   312.721039   31.100000  NaN   30.340000
# 2010-01-05   30.798571   135.479996   311.891449   31.100000  NaN   30.464285
# 2010-01-06   30.747143   134.729996   310.907837   31.080000  NaN   30.107143
# 2010-01-07   30.285715   132.320007   303.029083   30.700001  NaN   29.864286
# 2010-01-08   30.285715   133.679993   299.675903   30.879999  NaN   29.865715
# 2010-01-11   30.428572   132.800003   300.276978   30.760000  NaN   29.778572
# 2010-01-12   29.967142   129.820007   297.147339   30.400000  NaN   29.488571
# 2010-01-13   30.132856   129.710007   292.288940   30.520000  NaN   29.157143
# ...

# %%
p.major_axis
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-5cdf808b2fac> in <module>
# ----> 1 p.major_axis
#
# D:\study\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'DataFrame' object has no attribute 'major_axis'

# %%
p.transpose(major,itemaxis,minor)
p.swapaxes()
