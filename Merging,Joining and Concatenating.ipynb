# %%
import pandas as pd

# %%
w1=pd.read_csv("Restaurant - Week 1 Sales.csv")
w2=pd.read_csv("Restaurant - Week 2 Sales.csv")
cust=pd.read_csv("Restaurant - Customers.csv")
food=pd.read_csv("Restaurant - Foods.csv",index_col="Food ID")
sati=pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
w1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          147        8
# 221          745        4
# 222          184        3
# ...

# %%
w2
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# 5            310        5
# 6            761        2
# 7            443        5
# 8            729        9
# 9            741        8
# 10           847        6
# 11           156       10
# 12           550        7
# 13           620       10
# 14           272        4
# 15           511        2
# 16             8        6
# 17           534        7
# 18           909        6
# 19           732        9
# 20           372        4
# 21           713        1
# 22           496        3
# 23           381        9
# 24            13        2
# 25           101        4
# 26           325        7
# 27           674        2
# 28           564        8
# 29           578        5
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# ...

# %%
cust
# Out:
#        ID First Name Last Name  Gender        Company  \
# 0       1     Joseph   Perkins    Male        Dynazzy
# 1       2   Jennifer   Alvarez  Female           DabZ
# 2       3      Roger     Black    Male        Tagfeed
# 3       4     Steven     Evans    Male           Fatz
# 4       5       Judy  Morrison  Female        Demivee
# 5       6     Amanda    Howell  Female  Thoughtbridge
# 6       7     Johnny      Reid    Male    Babblestorm
# 7       8    Frances     Adams  Female       Dabshots
# 8       9    Gregory   Chapman    Male           Eayo
# 9      10     Steven      Ryan    Male        Twinder
# 10     11    Michael  Reynolds    Male         Meevee
# 11     12       Lois   Watkins  Female           Mydo
# 12     13       Ruth   Alvarez  Female    Twitterlist
# 13     14       Adam      Ryan    Male       Photojam
# 14     15      Jesse  Richards    Male        Demimbu
# 15     16      Scott    Arnold    Male          Meemm
# ...

# %%
food
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49
# 5        6       Pasta  13.99
# 6        7       Steak  24.99
# 7        8       Salad  11.25
# 8        9       Donut   0.99
# 9       10       Drink   1.75

# %%
sati
# Out:
#      Satisfaction Rating
# 0                      2
# 1                      7
# 2                      3
# 3                      7
# 4                     10
# 5                      3
# 6                      2
# 7                      5
# 8                     10
# 9                      7
# 10                     7
# 11                     5
# 12                     3
# 13                     2
# 14                     7
# 15                     4
# 16                     6
# 17                     1
# 18                     5
# 19                     5
# 20                     3
# 21                     2
# 22                     3
# 23                    10
# 24                     4
# 25                     9
# 26                     1
# 27                     4
# 28                     4
# 29                     9
# ..                   ...
# 220                    3
# 221                    8
# 222                    4
# 223                    2
# 224                    5
# ...

# %% [markdown]
# ## concat

# %%
b=pd.concat([w1,w2])
b
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# ...

# %%
a=pd.concat([w1,w2],ignore_index=True)
a
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 470          495        2
# 471          794        6
# 472          734       10
# ...

# %%
a.loc[230]
# Out:
# Customer ID    584
# Food ID         10
# Name: 230, dtype: int64

# %%
b.loc[230]
# Out:
#      Customer ID  Food ID
# 230          584       10
# 230          143        4

# %%
sale=pd.concat([w1,w2],keys=["1st week","2nd week"])
sale
# Out:
#               Customer ID  Food ID
# 1st week 0            537        9
#          1             97        4
#          2            658        1
#          3            202        2
#          4            155        9
#          5            213        8
#          6            600        1
#          7            503        5
#          8             71        3
#          9            174        3
#          10           961        9
#          11           966        5
#          12           641        4
#          13           288        2
#          14           149        4
#          15           954        2
#          16           147        9
#          17           155        1
#          18           550        6
#          19           101        7
#          20           549        6
#          21            75        6
#          22            78        7
#          23           514        5
#          24           833        7
#          25           329        8
# ...

# %%
sale.ix["1st week"]
# Out:
# D:\study\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# ...

# %%
sale.ix[("2nd week",134)]
# Out:
# D:\study\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Customer ID    46
# Food ID         6
# Name: (2nd week, 134), dtype: int64

# %%
sale.ix[("2nd week",210),"Food ID"]
# Out:
# D:\study\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 1

# %%
pd.concat([w1,w2],ignore_index=True,keys=["1stweek","2ndweek"])#ignore_index & keys will not work simultaneously
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 470          495        2
# 471          794        6
# 472          734       10
# ...

# %%
w1.append(w2)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# ...

# %% [markdown]
# ## join

# %%
w1.merge(w2,how="inner",on="Customer ID") #x-w1,y-w #it will not remove duplicate rows,example cid=155,described below
# Out:
#     Customer ID  Food ID_x  Food ID_y
# 0           537          9          5
# 1           155          9          3
# 2           155          1          3
# 3           503          5          8
# 4           503          5          9
# 5           550          6          7
# 6           101          7          4
# 7            75          6          4
# 8            77          1          7
# 9            77          9          7
# 10           77          2          7
# 11           77          9          7
# 12          628          4          7
# 13          798          9          5
# 14          798          1          5
# 15          462          3          8
# 16          304          3          3
# 17          304          2          3
# 18          189          4          5
# 19          799          8          7
# 20           30          2          4
# 21          249          9          6
# 22          677         10          3
# 23          741          3          8
# ...

# %%
w1[w1["Customer ID"]==155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
w2[w2["Customer ID"]==155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %%
w1.merge(w2,how="inner",on="Customer ID",suffixes=('_1st', '_2nd'))
# Out:
#     Customer ID  Food ID_1st  Food ID_2nd
# 0           537            9            5
# 1           155            9            3
# 2           155            1            3
# 3           503            5            8
# 4           503            5            9
# 5           550            6            7
# 6           101            7            4
# 7            75            6            4
# 8            77            1            7
# 9            77            9            7
# 10           77            2            7
# 11           77            9            7
# 12          628            4            7
# 13          798            9            5
# 14          798            1            5
# 15          462            3            8
# 16          304            3            3
# 17          304            2            3
# 18          189            4            5
# 19          799            8            7
# 20           30            2            4
# ...

# %%
w1.merge(w2,how="inner",on=["Customer ID","Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
w1.ix[w1["Customer ID"]==21]
# Out:
# D:\study\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#      Customer ID  Food ID
# 101           21        4
# 212           21        4

# %%
w2.ix[w2["Customer ID"]==21]
# Out:
# D:\study\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#     Customer ID  Food ID
# 30           21        4

# %%
w1.ix[w1["Customer ID"]==578]
# Out:
# D:\study\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#      Customer ID  Food ID
# 224          578        5

# %%
w2.ix[w2["Customer ID"]==578]
# Out:
# D:\study\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#      Customer ID  Food ID
# 29           578        5
# 189          578        5

# %% [markdown]
# ## outer join

# %%
w1.merge(w2,on="Customer ID",how="outer")  #full outer join
# Out:
#      Customer ID  Food ID_x  Food ID_y
# 0            537        9.0        5.0
# 1             97        4.0        NaN
# 2            658        1.0        NaN
# 3            202        2.0        NaN
# 4            155        9.0        3.0
# 5            155        1.0        3.0
# 6            213        8.0        NaN
# 7            600        1.0        NaN
# 8            503        5.0        8.0
# 9            503        5.0        9.0
# 10            71        3.0        NaN
# 11            71        8.0        NaN
# 12           174        3.0        NaN
# 13           961        9.0        NaN
# 14           966        5.0        NaN
# 15           641        4.0        NaN
# 16           288        2.0        NaN
# 17           149        4.0        NaN
# 18           954        2.0        NaN
# 19           147        9.0        NaN
# 20           147        8.0        NaN
# 21           550        6.0        7.0
# 22           101        7.0        4.0
# ...

# %%
a=w1.merge(w2,on="Customer ID",how="outer",indicator=True)
a
# Out:
#      Customer ID  Food ID_x  Food ID_y      _merge
# 0            537        9.0        5.0        both
# 1             97        4.0        NaN   left_only
# 2            658        1.0        NaN   left_only
# 3            202        2.0        NaN   left_only
# 4            155        9.0        3.0        both
# 5            155        1.0        3.0        both
# 6            213        8.0        NaN   left_only
# 7            600        1.0        NaN   left_only
# 8            503        5.0        8.0        both
# 9            503        5.0        9.0        both
# 10            71        3.0        NaN   left_only
# 11            71        8.0        NaN   left_only
# 12           174        3.0        NaN   left_only
# 13           961        9.0        NaN   left_only
# 14           966        5.0        NaN   left_only
# 15           641        4.0        NaN   left_only
# 16           288        2.0        NaN   left_only
# ...

# %%
a["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
b=a["_merge"].isin(["left_only","right_only"])
a[b]
# Out:
#      Customer ID  Food ID_x  Food ID_y      _merge
# 1             97        4.0        NaN   left_only
# 2            658        1.0        NaN   left_only
# 3            202        2.0        NaN   left_only
# 6            213        8.0        NaN   left_only
# 7            600        1.0        NaN   left_only
# 10            71        3.0        NaN   left_only
# 11            71        8.0        NaN   left_only
# 12           174        3.0        NaN   left_only
# 13           961        9.0        NaN   left_only
# 14           966        5.0        NaN   left_only
# 15           641        4.0        NaN   left_only
# 16           288        2.0        NaN   left_only
# 17           149        4.0        NaN   left_only
# 18           954        2.0        NaN   left_only
# 19           147        9.0        NaN   left_only
# 20           147        8.0        NaN   left_only
# 23           549        6.0        NaN   left_only
# ...

# %% [markdown]
# ## left join

# %%
w2.merge(cust,how="left",right_on="ID",left_on="Customer ID")
# Out:
#      Customer ID  Food ID   ID   First Name   Last Name  Gender       Company  \
# 0            688       10  688         Carl  Williamson    Male    Thoughtmix
# 1            813        7  813       Johnny      Walker    Male        Kayveo
# 2            495       10  495      Deborah      Little  Female    Babbleblab
# 3            189        5  189        Roger      Gordon    Male       Skilith
# 4            267        3  267      Matthew        Wood    Male        Agimba
# 5            310        5  310        Bobby        Sims    Male     Skynoodle
# 6            761        2  761    Stephanie       Olson  Female     Rhynoodle
# 7            443        5  443       Robert    Thompson    Male          Oozz
# 8            729        9  729        Roger    Lawrence    Male        Wikizz
# 9            741        8  741        Diana       Welch  Female          Eayo
# 10           847        6  847        Irene       Owens  Female         Yabox
# ...

# %% [markdown]
# left_on and right_on are used generally when one column of one table has same value with anathor column of different table but those two columns have different name.It can be used in inner,outer,left,right join.

# %% [markdown]
# ## merging index col

# %%
cust=pd.read_csv("Restaurant - Customers.csv",index_col="ID")

# %%
cust.head()
# Out:
#    First Name Last Name  Gender  Company                     Occupation
# ID
# 1      Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 2    Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 3       Roger     Black    Male  Tagfeed              Account Executive
# 4      Steven     Evans    Male     Fatz               Registered Nurse
# 5        Judy  Morrison  Female  Demivee                Legal Assistant

# %%
w1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
s=w1.merge(cust,how="left",left_on="Customer ID",right_index=True,indicator=True)

# %%
s.merge(food,how="left",left_on="Food ID",right_index=True)
# Out:
#      Customer ID  Food ID First Name  Last Name  Gender       Company  \
# 0            537        9     Cheryl    Carroll  Female      Zoombeat
# 1             97        4     Amanda    Watkins  Female           Ozu
# 2            658        1    Patrick       Webb    Male     Browsebug
# 3            202        2      Louis   Campbell    Male     Rhynoodle
# 4            155        9    Carolyn       Diaz  Female      Gigazoom
# 5            213        8      Keith     Foster    Male     Gigashots
# 6            600        1     Sandra     Bailey  Female     Jaxnation
# 7            503        5     Justin    Daniels    Male          Oloo
# 8             71        3    Carolyn      Reyes  Female        Twimbo
# 9            174        3       Anna     Miller  Female       Innojam
# 10           961        9      Ralph   Richards    Male  Thoughtstorm
# 11           966        5     Robert       Ford    Male    Jabbertype
# ...

# %%
w1.merge(w2,how="left",left_index=True,right_index=True)
# Out:
#      Customer ID_x  Food ID_x  Customer ID_y  Food ID_y
# 0              537          9            688         10
# 1               97          4            813          7
# 2              658          1            495         10
# 3              202          2            189          5
# 4              155          9            267          3
# 5              213          8            310          5
# 6              600          1            761          2
# 7              503          5            443          5
# 8               71          3            729          9
# 9              174          3            741          8
# 10             961          9            847          6
# 11             966          5            156         10
# 12             641          4            550          7
# 13             288          2            620         10
# 14             149          4            272          4
# 15             954          2            511          2
# ...

# %% [markdown]
# ## join()

# %% [markdown]
# join method generally used where merging two df whch have exact same index and basically we put one df to the right pf otheror basically added like.

# %%
w1.merge(sati,how="left",left_index=True,right_index=True)
# Out:
#      Customer ID  Food ID  Satisfaction Rating
# 0            537        9                    2
# 1             97        4                    7
# 2            658        1                    3
# 3            202        2                    7
# 4            155        9                   10
# 5            213        8                    3
# 6            600        1                    2
# 7            503        5                    5
# 8             71        3                   10
# 9            174        3                    7
# 10           961        9                    7
# 11           966        5                    5
# 12           641        4                    3
# 13           288        2                    2
# 14           149        4                    7
# 15           954        2                    4
# 16           147        9                    6
# 17           155        1                    1
# 18           550        6                    5
# ...

# %%
w1.join(sati)
# Out:
#      Customer ID  Food ID  Satisfaction Rating
# 0            537        9                    2
# 1             97        4                    7
# 2            658        1                    3
# 3            202        2                    7
# 4            155        9                   10
# 5            213        8                    3
# 6            600        1                    2
# 7            503        5                    5
# 8             71        3                   10
# 9            174        3                    7
# 10           961        9                    7
# 11           966        5                    5
# 12           641        4                    3
# 13           288        2                    2
# 14           149        4                    7
# 15           954        2                    4
# 16           147        9                    6
# 17           155        1                    1
# 18           550        6                    5
# ...

# %% [markdown]
# ## pd.merge()

# %%
pd.merge(w1,cust,how="inner",left_on="Customer ID",right_on="ID")
# Out:
#      Customer ID  Food ID First Name  Last Name  Gender       Company  \
# 0            537        9     Cheryl    Carroll  Female      Zoombeat
# 1             97        4     Amanda    Watkins  Female           Ozu
# 2            658        1    Patrick       Webb    Male     Browsebug
# 3            202        2      Louis   Campbell    Male     Rhynoodle
# 4            155        9    Carolyn       Diaz  Female      Gigazoom
# 5            155        1    Carolyn       Diaz  Female      Gigazoom
# 6            213        8      Keith     Foster    Male     Gigashots
# 7            600        1     Sandra     Bailey  Female     Jaxnation
# 8            503        5     Justin    Daniels    Male          Oloo
# 9             71        3    Carolyn      Reyes  Female        Twimbo
# 10            71        8    Carolyn      Reyes  Female        Twimbo
# 11           174        3       Anna     Miller  Female       Innojam
# ...
